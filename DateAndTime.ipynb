# %%
import numpy as np
import pandas as pd

# %%
date = pd.read_csv('orders.txt')
time = pd.read_csv('messages.txt')

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
time.head()
# Out:
#                   date                                                msg
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %%
#in numpy array date time is prsent as object datatype means as string
#so need to convert to proper format

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
#Working with Dates

# %%
# Converting to datetime datatype
date['date'] = pd.to_datetime(date['date'])

# %%
date.info() #now changed to datatime data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %%
#Extract year

date['date_year'] = date['date'].dt.year

date.sample(2)
# Out:
#           date  product_id  city_id  orders  date_year
# 582 2019-07-22        1031        0       1       2019
# 99  2019-04-13        6206        2      24       2019

# %%
#Extract Month

date['date_month_no'] = date['date'].dt.month

date.head(2)
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
#
#   date_month_name  date_day
# 0        December        10
# 1          August        15

# %%
#extracting month name
date['date_month_name'] = date['date'].dt.month_name()

date.head(2)
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
#
#   date_month_name  date_day
# 0        December        10
# 1          August        15

# %%
#Extract Days

date['date_day'] = date['date'].dt.day

date.head(2)
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
#
#   date_month_name  date_day
# 0        December        10
# 1          August        15

# %%
# day of week

date['date_dow'] = date['date'].dt.dayofweek

date.head(2)
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
#
#   date_month_name  date_day  date_dow
# 0        December        10         1
# 1          August        15         2

# %%
# day of week - name

date['date_dow_name'] = date['date'].dt.day_name()

date.drop(columns=['product_id','city_id','orders']).head(2)
# Out:
#         date  date_year  date_month_no date_month_name  date_day  date_dow  \
# 0 2019-12-10       2019             12        December        10         1
# 1 2018-08-15       2018              8          August        15         2
#
#   date_dow_name
# 0       Tuesday
# 1     Wednesday

# %%
# is weekend?

date['date_is_weekend'] = np.where(date['date_dow_name'].isin(['Sunday', 'Saturday']), 1,0)

date.drop(columns=['product_id','city_id','orders']).head(2)
# Out:
#         date  date_year  date_month_no date_month_name  date_day  date_dow  \
# 0 2019-12-10       2019             12        December        10         1
# 1 2018-08-15       2018              8          August        15         2
#
#   date_dow_name  date_is_weekend
# 0       Tuesday                0
# 1     Wednesday                0

# %%
#Extract week of the year
date['date_week'] = date['date'].dt.week

date.drop(columns=['product_id','city_id','orders']).head(2)
# Out:
# <ipython-input-36-32931d89b850>:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   date['date_week'] = date['date'].dt.week
#         date  date_year  date_month_no date_month_name  date_day  date_dow  \
# 0 2019-12-10       2019             12        December        10         1
# 1 2018-08-15       2018              8          August        15         2
#
#   date_dow_name  date_is_weekend  date_week
# 0       Tuesday                0         50
# 1     Wednesday                0         33

# %%
#Extract Quarter
date['quarter'] = date['date'].dt.quarter

date.drop(columns=['product_id','city_id','orders']).head(2)
# Out:
#         date  date_year  date_month_no date_month_name  date_day  date_dow  \
# 0 2019-12-10       2019             12        December        10         1
# 1 2018-08-15       2018              8          August        15         2
#
#   date_dow_name  date_is_weekend  date_week  quarter
# 0       Tuesday                0         50        4
# 1     Wednesday                0         33        3

# %%
#Extract Semester
date['semester'] = np.where(date['quarter'].isin([1,2]), 1, 2)

date.drop(columns=['product_id','city_id','orders']).head(2)
# Out:
#         date  date_year  date_month_no date_month_name  date_day  date_dow  \
# 0 2019-12-10       2019             12        December        10         1
# 1 2018-08-15       2018              8          August        15         2
#
#   date_dow_name  date_is_weekend  date_week  quarter  semester
# 0       Tuesday                0         50        4         2
# 1     Wednesday                0         33        3         2

# %%
#Extract Time elapsed between dates

# %%
import datetime

today = datetime.datetime.today()

today #for getting todays date time
# Out:
# datetime.datetime(2023, 7, 25, 17, 11, 7, 740157)

# %%
str(today)
# Out:
# '2023-07-25 17:11:07.740157'

# %%
today - date['date'] #direct subtract get from that day time to today difference

#it gives series
# Out:
# 0     1323 days 17:11:07.740157
# 1     1805 days 17:11:07.740157
# 2     1736 days 17:11:07.740157
# 3     1438 days 17:11:07.740157
# 4     1661 days 17:11:07.740157
#                  ...
# 995   1751 days 17:11:07.740157
# 996   1692 days 17:11:07.740157
# 997   1540 days 17:11:07.740157
# 998   1605 days 17:11:07.740157
# 999   1379 days 17:11:07.740157
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
(today - date['date']).dt.days
# Out:
# 0      1323
# 1      1805
# 2      1736
# 3      1438
# 4      1661
#        ...
# 995    1751
# 996    1692
# 997    1540
# 998    1605
# 999    1379
# Name: date, Length: 1000, dtype: int64

# %%
# Months passed

np.round((today -date['date']) / np.timedelta64(1, 'M'),0)
#for getting month difference
# Out:
# 0      43.0
# 1      59.0
# 2      57.0
# 3      47.0
# 4      55.0
#        ...
# 995    58.0
# 996    56.0
# 997    51.0
# 998    53.0
# 999    45.0
# Name: date, Length: 1000, dtype: float64

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
# Converting to datetime datatype
time['date'] = pd.to_datetime(time['date'])

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
#  1   msg     1000 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 15.8+ KB

# %%
time['hour'] = time['date'].dt.hour
time['min'] = time['date'].dt.minute
time['sec'] = time['date'].dt.second

time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  min  sec
# 0     0   50    0
# 1    23   40    0
# 2     0   21    0
# 3     0   31    0
# 4    23   11    0

# %%
#Extract Time part
time['time'] = time['date'].dt.time

time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  min  sec      time
# 0     0   50    0  00:50:00
# 1    23   40    0  23:40:00
# 2     0   21    0  00:21:00
# 3     0   31    0  00:31:00
# 4    23   11    0  23:11:00

# %%
today - time['date']
# Out:
# 0     3509 days 16:21:07.740157
# 1     3373 days 17:31:07.740157
# 2     3859 days 16:50:07.740157
# 3     3161 days 16:40:07.740157
# 4     3558 days 18:00:07.740157
#                  ...
# 995   4148 days 16:21:07.740157
# 996   3469 days 17:57:07.740157
# 997   3934 days 17:34:07.740157
# 998   4050 days 17:37:07.740157
# 999   3322 days 17:46:07.740157
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
# in seconds

(today - time['date'])/np.timedelta64(1,'s')
# Out:
# 0      3.032365e+08
# 1      2.914903e+08
# 2      3.334782e+08
# 3      2.731704e+08
# 4      3.074760e+08
#            ...
# 995    3.584461e+08
# 996    2.997862e+08
# 997    3.399608e+08
# 998    3.499834e+08
# 999    2.870848e+08
# Name: date, Length: 1000, dtype: float64

# %%
# in minutes

(today - time['date'])/np.timedelta64(1,'m')
# Out:
# 0      5.053941e+06
# 1      4.858171e+06
# 2      5.557970e+06
# 3      4.552840e+06
# 4      5.124600e+06
#            ...
# 995    5.974101e+06
# 996    4.996437e+06
# 997    5.666014e+06
# 998    5.833057e+06
# 999    4.784746e+06
# Name: date, Length: 1000, dtype: float64

# %%
# in hours

(today - time['date'])/np.timedelta64(1,'h')
# Out:
# 0      84232.352150
# 1      80969.518817
# 2      92632.835483
# 3      75880.668817
# 4      85410.002150
#            ...
# 995    99568.352150
# 996    83273.952150
# 997    94433.568817
# 998    97217.618817
# 999    79745.768817
# Name: date, Length: 1000, dtype: float64
